# %%
# This script converts MIDI files from the dataset described in the thesis into WAV files, enabling the use of the pipeline described in the thesis

from pathlib import Path
import numpy as np
import pretty_midi
import soundfile as sf

# Define the paths that will be used throughout
DATA_ROOT = Path('/Users/zorkabozilovic/Desktop/PART1')
STIMULUS_DIR = DATA_ROOT / 'diliBach_midi_4dryad'
WAV_OUTPUT_DIR = DATA_ROOT / 'diliBach_wav_4dryad'
WAV_OUTPUT_DIR.mkdir(exist_ok=True)

# Convert MIDI to WAV, trim leading silence and normalize amplitude
def convert_midi_to_wav(fs=44100, gain=0.1, trim_thresh=1e-4):
    
    for i in range(1, 11):
        midi_file = STIMULUS_DIR / f'audio{i}.mid'
        wav_file = WAV_OUTPUT_DIR / f'{i}.wav'

        try:
            midi = pretty_midi.PrettyMIDI(str(midi_file))

            # Render audio (use built-in synthesiser)
            audio = midi.synthesize(fs=fs)

            # Trim leading silence (based on amplitude threshold (1e-4))
            abs_audio = np.abs(audio)
            nonzero_idx = np.where(abs_audio > trim_thresh)[0]
            if len(nonzero_idx) > 0:
                start_idx = nonzero_idx[0]
                audio = audio[start_idx:]
            else:
                continue

            # Normalize amplitude (so peak equals 0.1 (gain))
            max_amp = np.max(np.abs(audio))
            if max_amp > 0:
                audio = audio * (gain / max_amp)
            else:
                continue

            # Save WAV
            sf.write(str(wav_file), audio, fs)
            duration = len(audio) / fs
            print(f"Saved {wav_file.name} (duration: {duration:.1f}s)")

        except Exception as e:
            print(f"Failed to convert {midi_file.name}: {e}")

# Convert MIDI files to WAV
convert_midi_to_wav()
# Out:
# Saved 1.wav (duration: 158.0s)
# Saved 2.wav (duration: 153.1s)
# Saved 3.wav (duration: 119.3s)
# Saved 4.wav (duration: 134.5s)
# Saved 5.wav (duration: 164.7s)
# Saved 6.wav (duration: 198.3s)
# Saved 7.wav (duration: 172.2s)
# Saved 8.wav (duration: 181.2s)
# Saved 9.wav (duration: 133.2s)
# Saved 10.wav (duration: 177.1s)
